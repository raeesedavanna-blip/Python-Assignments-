# %% [markdown]
# **Python Assignment 2: Data Structures - List, Dictionary, Set & Conditional Statements**

# %% [markdown]
# **List (Creation, Modification and Access):**
#
# **1. List Creation:**

# %%
# a. Create a list named age_list with five integer elements. For eg., [24, 25, 26, 27, 28]
age_list = [24,25,26,27,28]
print(age_list)
print(type(age_list))
# Out:
# [24, 25, 26, 27, 28]
# <class 'list'>

# %%
#b. Create a list named name_list with five string elements.
name_list = ["Raj","John","Bob","Nivin","Aju"]
print(name_list)
print(type(name_list))
# Out:
# ['Raj', 'John', 'Bob', 'Nivin', 'Aju']
# <class 'list'>

# %% [markdown]
# **2. List Operations / Modifications:**

# %%
# a. Append the string "Yazhini" to name_list.
name_list.append("Yazhini")
print(name_list)
# Out:
# ['Raj', 'John', 'Bob', 'Nivin', 'Aju', 'Yazhini']

# %%
#b. Insert the element 30 at index 2 in age_list.
age_list.insert(2,30)
print(age_list)
# Out:
# [24, 25, 30, 26, 27, 28]

# %%
#c. Remove the string "Yazhini" from name_list.

name_list.remove("Yazhini")
print(name_list)
# Out:
# ['Raj', 'John', 'Bob', 'Nivin', 'Aju']

# %%
#d. Pop the last element from age_list.
age_list.pop()
print(age_list)
# Out:
# [24, 25, 30, 26, 27]

# %%
#e. Extend the age_list with additional ages [29, 30, 26].
age_list.extend([29,30,26])
print(age_list)
# Out:
# [24, 25, 30, 26, 27, 29, 30, 26]

# %%
#f. Sort age_list in descending order.
age_list.sort(reverse=True)
print(age_list)
# Out:
# [30, 30, 29, 27, 26, 26, 25, 24]

# %%
#g. Find Max age, Min age and sum of all ages from age_list.

max_age = max(age_list)
min_age = min(age_list)
sum_age = sum(age_list)

print("Max age:", max_age)
print("Min age:", min_age)
print("Sum of all ages:", sum_age)
# Out:
# Max age: 30
# Min age: 24
# Sum of all ages: 217

# %% [markdown]
# **3. Accessing List Elements:**

# %%
#a. Print the first element of name_list.
print(name_list[0])
# Out:
# Raj

# %%
#b. Print the last element of name_list.
print(name_list[-1])
# Out:
# Aju

# %%
#c. Print the elements from index 2 to index 4 in name_list.
print(name_list[2:5])
# Out:
# ['Bob', 'Nivin', 'Aju']

# %%
#d. Print the elements of name_list in reverse order.
print(name_list[::-1])
# Out:
# ['Aju', 'Nivin', 'Bob', 'John', 'Raj']

# %% [markdown]
# **Dictionary (Creation, Modification and Access):**

# %%
#a. Create a dictionary named student_marks that maps the names of five students to their marks (use scale of from 0 to 100).
student_marks = {"Raj": 80,"John": 92,"Bob": 78,"Nivin": 95, "Aju": 88}
print(student_marks)
print(type(student_marks))
# Out:
# {'Raj': 80, 'John': 92, 'Bob': 78, 'Nivin': 95, 'Aju': 88}
# <class 'dict'>

# %%
#b. Access and print the mark of a specific student, of your choice.

print("Bobs Mark :",student_marks["Bob"])
# Out:
# Bobs Mark : 78

# %%
#c. Add a new student "Janani" with a mark of 80 to the student_marks dictionary.
student_marks["Janani"]=80
print(student_marks)
# Out:
# {'Raj': 80, 'John': 92, 'Bob': 78, 'Nivin': 95, 'Aju': 88, 'Janani': 80}

# %%
#d. Update the mark of any one older student to 82.
student_marks["Raj"]=82
print(student_marks)
# Out:
# {'Raj': 82, 'John': 92, 'Bob': 78, 'Nivin': 95, 'Aju': 88, 'Janani': 80}

# %%
#e. Use the keys(), values(), and items() methods to print all keys, values, and key-value pairs in the student_marks dictionary.
keys = student_marks.keys()
print("Keys:", keys)

values = student_marks.values()
print("Values:", values)

items = student_marks.items()
print("Key-Value Pairs:", items)
# Out:
# Keys: dict_keys(['Raj', 'John', 'Bob', 'Nivin', 'Aju', 'Janani'])
# Values: dict_values([82, 92, 78, 95, 88, 80])
# Key-Value Pairs: dict_items([('Raj', 82), ('John', 92), ('Bob', 78), ('Nivin', 95), ('Aju', 88), ('Janani', 80)])

# %% [markdown]
# **Sets (Operations):**

# %%
#a. Create a set called my_set with following values:
#['a','e','i','o','u','a','a','i']
#Analyse the output and provide explanation for the same.

my_set = {'a','e','i','o','u','a','a','i'}
print(my_set)
print(type(my_set))
# Out:
# {'i', 'o', 'e', 'u', 'a'}
# <class 'set'>

# %% [markdown]
# Analyse the output and provide explanation for the same.
#
# Answer :set only store unique elements

# %%
#b. Attempt to change the value of my_set[4] = 's'. If code throws an error,
#provide an explanation.
my_set[4]="s"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_516/4162841224.py in <cell line: 0>()
#       1 #b. Attempt to change the value of my_set[4] = 's'. If code throws an error,
#       2 #provide an explanation.
# ----> 3 my_set[4]="s"
#
# TypeError: 'set' object does not support item assignment

# %% [markdown]
# Error Explanation
#
# sets are unordered collection of elements which cannot be accessed by index

# %%
#c. Create two sets:
#set1 with values: {1, 3, 5, 7, 9}
#set2 with values: {2, 3, 5, 8, 10}

set1 = {1, 3, 5, 7, 9}
set2 = {2, 3, 5, 8, 10}

# %%
#d. Compute and print the union and intersection of set1 and set2.
union_set = set1.union(set2)
print("Union of set1 and set2:", union_set)

intersection_set = set1.intersection(set2)
print("Intersection of set1 and set2:", intersection_set)
# Out:
# Union of set1 and set2: {1, 2, 3, 5, 7, 8, 9, 10}
# Intersection of set1 and set2: {3, 5}

# %% [markdown]
# **Operators & Conditional Statements :**(IF, ELIF, ELSE)
#
# Performance Category Program:

# %%
#1. Prompt user for Input. Score range should be from 0 to 10 (both inclusive).
score = (float(input("Enter your score (1 - 10):")))
# Out:
# Enter your score (1 - 10):1

# %% [markdown]
# 2. Find the performance category based on the input score using following criteria:
# a. Above Average: Score greater than 7
# b. Average: Score between 4 and 7(both inclusive)
# c. Below Average: Score lesser than 4

# %%
score = (float(input("Enter your score (1 - 10):")))

if score > 7:
   print("Above Average")
elif score >= 4 and score <= 7:
    print("Average")
else:
    print("Below Average")
# Out:
# Enter your score (1 - 10):9
# Above Average

# %%
#3,4. Output: Print the Performance category

score = (float(input("Enter your score (1 - 10):")))

if score > 7:
   print("Your Performance Category is Above Average Keep up the good work!!")
elif score >= 4 and score <= 7:
    print("Your Performance Category is  Average Good Job , Need improvement")
else:
    print("Your Performance Category is  Below Average, There is long way to go")
# Out:
# Enter your score (1 - 10):7
# Your Performance Category is  Average Good Job , Need improvement
